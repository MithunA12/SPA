# %%
import matplotlib.pyplot as plt

# Example data (replace with your actual arrays)
age_men = [40, 60, 70, 50, 80]  # list or numpy array of ages
delta_power_men = [23.132077679406400, 22.116582824740900, 22.592912746119400, 21.698856850288100, 26.05035062343010]  # corresponding BP_abs_delta_C3-M2_N3
#20010-40M = 23.132077679406400
#20016-60M = 22.116582824740900
#20038-70M = 22.592912746119400
#20071-50M = 21.698856850288100
#200341-80M = 26.05035062343010
age_women = [60, 40, 50, 80, 70]  # list or numpy array of ages
delta_power_women = [22.82742628254520, 23.707136821793700, 20.359560319437700, 22.980472614211000, 22.08049959198880]  # corresponding BP_abs_delta_C3-M2_N3
#20061-60F = 22.82742628254520
#200142-40F = 23.707136821793700
#200154-50F = 20.359560319437700
#200191-80F = 22.980472614211000
#200270-70F = 22.08049959198880


#try bp_rel


plt.figure()
plt.scatter(age_men, delta_power_men, label='Men')
plt.scatter(age_women, delta_power_women, label='Women')

plt.xlabel('Age')
plt.ylabel('Delta Absolute Band Power (N3)')
plt.title('Age vs Delta Absolute Band Power (N3) - Central Channel')

plt.legend()

plt.show()
